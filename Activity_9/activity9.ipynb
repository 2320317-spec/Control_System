# %%
# %pip install sympy control matplotlib numpy
# Out:
# Requirement already satisfied: sympy in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (1.14.0)
# Requirement already satisfied: control in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (0.10.2)
# Requirement already satisfied: matplotlib in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (3.10.8)
# Requirement already satisfied: numpy in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (2.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (from sympy) (1.3.0)
# Requirement already satisfied: scipy>=1.8 in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (from control) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\lowel\OneDrive\Desktop\MYKE SCHOOL\Feedback and Control System\F-A-C-S\Control_System\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sympy as sp
from control import tf, step_response, poles, zeros, pzmap
import matplotlib.pyplot as plt
import numpy as np

#Define Symbols
s = sp.symbols('s')
X = sp.symbols('X')
Y = sp.symbols('Y')

# %%
#Equation: 2*s^2*Y + s*Y = s*X + X (Laplace)
A = 2*s**2 * Y + s * Y
B = s * X + X

# %%
#Solve for Y/X (Transfer Function)
tf_expr = sp.solve(sp.Eq(A, B), Y)[0] / X
tf_simplified = sp.simplify(tf_expr)

print(f"Calculated Transfer Function G(s): {tf_simplified}")
# Out:
# Calculated Transfer Function G(s): (s + 1)/(s*(2*s + 1))

# %%
num_coeffs = [float(c) for c in sp.Poly(sp.numer(tf_simplified), s).all_coeffs()]
den_coeffs = [float(c) for c in sp.Poly(sp.denom(tf_simplified), s).all_coeffs()]

sys = tf(num_coeffs, den_coeffs)
print(sys)
# Out:
# <TransferFunction>: sys[3]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#     s + 1
#   ---------
#   2 s^2 + s

# %%
#Poles and zeros output value
print(f"Poles: {poles(sys)}")
print(f"Zeros: {zeros(sys)}")
# Out:
# Poles: [-0.5+0.j  0. +0.j]
# Zeros: [-1.+0.j]

# %%
#Plot Step Response
t, y = step_response(sys)
plt.plot(t, y)
plt.title('Step Response')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
#Poles and Zeros
pzmap(sys, grid=True)
plt.show()
